# %% [markdown]
# # Loan Payback Prediction - XGBoost Model
#
# ## Goal
# Predict the probability that a borrower will pay back their loan using an XGBoost model with Cross-Validation.
#
# ## Steps
# 1.  Data Loading
# 2.  Feature Engineering
# 3.  Model Training (Stratified K-Fold CV)
# 4.  Submission Generation

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OrdinalEncoder
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Data Loading

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
sample_submission = pd.read_csv('data/sample_submission.csv')

print(f"Train shape: {train_df.shape}")
print(f"Test shape: {test_df.shape}")
# Out:
# Train shape: (593994, 13)
# Test shape: (254569, 12)

# %% [markdown]
# ## 2. Feature Engineering

# %%
# Combine for consistent encoding
train_df['is_train'] = 1
test_df['is_train'] = 0
test_df['loan_paid_back'] = np.nan

full_df = pd.concat([train_df, test_df], axis=0).reset_index(drop=True)

# 1. Log Transformation for skewed features
skewed_features = ['annual_income', 'loan_amount', 'debt_to_income_ratio']
for col in skewed_features:
    full_df[col] = np.log1p(full_df[col])

# 2. Ordinal Encoding for grade_subgrade
# Create a mapping from A1..G5 to 1..35
grades = sorted(full_df['grade_subgrade'].unique())
grade_map = {grade: i for i, grade in enumerate(grades)}
full_df['grade_subgrade_encoded'] = full_df['grade_subgrade'].map(grade_map)

# 3. One-Hot Encoding for other categoricals
categorical_cols = ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose']
full_df = pd.get_dummies(full_df, columns=categorical_cols, drop_first=True)

# Drop original grade_subgrade and id
full_df.drop(['grade_subgrade', 'id'], axis=1, inplace=True)

# Split back
train_processed = full_df[full_df['is_train'] == 1].drop(['is_train'], axis=1)
test_processed = full_df[full_df['is_train'] == 0].drop(['is_train', 'loan_paid_back'], axis=1)

X = train_processed.drop('loan_paid_back', axis=1)
y = train_processed['loan_paid_back']
X_test = test_processed

print(f"Processed Train shape: {X.shape}")
print(f"Processed Test shape: {X_test.shape}")
# Out:
# Processed Train shape: (593994, 26)
# Processed Test shape: (254569, 26)

# %% [markdown]
# ## 3. Model Training (Stratified K-Fold CV)

# %%
# Calculate scale_pos_weight
num_pos = y.sum()
num_neg = len(y) - num_pos
scale_pos_weight = num_neg / num_pos

print(f"Scale Pos Weight: {scale_pos_weight:.4f}")

FOLDS = 5
skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)

oof_preds = np.zeros(X.shape[0])
test_preds = np.zeros(X_test.shape[0])
cv_scores = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    model = xgb.XGBClassifier(
        n_estimators=5000,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        scale_pos_weight=scale_pos_weight,
        random_state=42,
        n_jobs=-1,
        early_stopping_rounds=4000,
        eval_metric='auc'
    )
    
    model.fit(
        X_train, y_train, 
        eval_set=[(X_val, y_val)], 
        verbose=100
    )
    
    val_preds = model.predict_proba(X_val)[:, 1]
    oof_preds[val_idx] = val_preds
    
    score = roc_auc_score(y_val, val_preds)
    cv_scores.append(score)
    print(f"Fold {fold+1} ROC AUC: {score:.5f}")
    
    # Predict on test set (average over folds)
    test_preds += model.predict_proba(X_test)[:, 1] / FOLDS

print(f"\nAverage CV ROC AUC: {np.mean(cv_scores):.5f}")
print(f"OOF ROC AUC: {roc_auc_score(y, oof_preds):.5f}")
# Out:
# Scale Pos Weight: 0.2518
# [0]	validation_0-auc:0.90792
# [100]	validation_0-auc:0.91802
# [200]	validation_0-auc:0.91980
# [300]	validation_0-auc:0.92081
# [400]	validation_0-auc:0.92147
# [500]	validation_0-auc:0.92214
# [600]	validation_0-auc:0.92251
# [700]	validation_0-auc:0.92269
# [800]	validation_0-auc:0.92280
# [900]	validation_0-auc:0.92274
# [1000]	validation_0-auc:0.92270
# [1100]	validation_0-auc:0.92264
# [1200]	validation_0-auc:0.92259
# [1300]	validation_0-auc:0.92248
# [1400]	validation_0-auc:0.92240
# [1500]	validation_0-auc:0.92222
# [1600]	validation_0-auc:0.92207
# [1700]	validation_0-auc:0.92197
# [1800]	validation_0-auc:0.92187
# [1900]	validation_0-auc:0.92176
# [2000]	validation_0-auc:0.92161
# [2100]	validation_0-auc:0.92149
# [2200]	validation_0-auc:0.92136
# [2300]	validation_0-auc:0.92114
# [2400]	validation_0-auc:0.92104
# [2500]	validation_0-auc:0.92090
# [2600]	validation_0-auc:0.92073
# [2700]	validation_0-auc:0.92055
# [2800]	validation_0-auc:0.92043
# [2900]	validation_0-auc:0.92022
# [3000]	validation_0-auc:0.92003
# [3100]	validation_0-auc:0.91989
# [3200]	validation_0-auc:0.91975
# [3300]	validation_0-auc:0.91959
# [3400]	validation_0-auc:0.91942
# [3500]	validation_0-auc:0.91929
# [3600]	validation_0-auc:0.91914
# [3700]	validation_0-auc:0.91897
# [3800]	validation_0-auc:0.91883
# [3900]	validation_0-auc:0.91867
# [4000]	validation_0-auc:0.91849
# [4100]	validation_0-auc:0.91833
# [4200]	validation_0-auc:0.91820
# [4300]	validation_0-auc:0.91807
# [4400]	validation_0-auc:0.91791
# [4500]	validation_0-auc:0.91779
# [4600]	validation_0-auc:0.91764
# [4700]	validation_0-auc:0.91750
# [4800]	validation_0-auc:0.91739
# [4815]	validation_0-auc:0.91737
# Fold 1 ROC AUC: 0.92280
# [0]	validation_0-auc:0.90718
# [100]	validation_0-auc:0.91714
# [200]	validation_0-auc:0.91917
# [300]	validation_0-auc:0.92029
# [400]	validation_0-auc:0.92102
# [500]	validation_0-auc:0.92157
# [600]	validation_0-auc:0.92194
# [700]	validation_0-auc:0.92213
# [800]	validation_0-auc:0.92228
# [900]	validation_0-auc:0.92229
# [1000]	validation_0-auc:0.92231
# [1100]	validation_0-auc:0.92236
# [1200]	validation_0-auc:0.92224
# [1300]	validation_0-auc:0.92211
# [1400]	validation_0-auc:0.92198
# [1500]	validation_0-auc:0.92194
# [1600]	validation_0-auc:0.92183
# [1700]	validation_0-auc:0.92171
# [1800]	validation_0-auc:0.92158
# [1900]	validation_0-auc:0.92144
# [2000]	validation_0-auc:0.92127
# [2100]	validation_0-auc:0.92113
# [2200]	validation_0-auc:0.92100
# [2300]	validation_0-auc:0.92085
# [2400]	validation_0-auc:0.92069
# [2500]	validation_0-auc:0.92054
# [2600]	validation_0-auc:0.92040
# [2700]	validation_0-auc:0.92028
# [2800]	validation_0-auc:0.92016
# [2900]	validation_0-auc:0.92004
# [3000]	validation_0-auc:0.91989
# [3100]	validation_0-auc:0.91971
# [3200]	validation_0-auc:0.91954
# [3300]	validation_0-auc:0.91938
# [3400]	validation_0-auc:0.91923
# [3500]	validation_0-auc:0.91908
# [3600]	validation_0-auc:0.91894
# [3700]	validation_0-auc:0.91878
# [3800]	validation_0-auc:0.91863
# [3900]	validation_0-auc:0.91850
# [4000]	validation_0-auc:0.91842
# [4100]	validation_0-auc:0.91825
# [4200]	validation_0-auc:0.91808
# [4300]	validation_0-auc:0.91795
# [4400]	validation_0-auc:0.91779
# [4500]	validation_0-auc:0.91764
# [4600]	validation_0-auc:0.91752
# [4700]	validation_0-auc:0.91736
# [4800]	validation_0-auc:0.91718
# [4900]	validation_0-auc:0.91707
# [4999]	validation_0-auc:0.91694
# Fold 2 ROC AUC: 0.92236
# [0]	validation_0-auc:0.90669
# [100]	validation_0-auc:0.91573
# [200]	validation_0-auc:0.91757
# [300]	validation_0-auc:0.91853
# [400]	validation_0-auc:0.91933
# [500]	validation_0-auc:0.91987
# [600]	validation_0-auc:0.92024
# [700]	validation_0-auc:0.92042
# [800]	validation_0-auc:0.92047
# [900]	validation_0-auc:0.92048
# [1000]	validation_0-auc:0.92048
# [1100]	validation_0-auc:0.92045
# [1200]	validation_0-auc:0.92035
# [1300]	validation_0-auc:0.92029
# [1400]	validation_0-auc:0.92023
# [1500]	validation_0-auc:0.92010
# [1600]	validation_0-auc:0.92000
# [1700]	validation_0-auc:0.91986
# [1800]	validation_0-auc:0.91976
# [1900]	validation_0-auc:0.91963
# [2000]	validation_0-auc:0.91952
# [2100]	validation_0-auc:0.91940
# [2200]	validation_0-auc:0.91930
# [2300]	validation_0-auc:0.91916
# [2400]	validation_0-auc:0.91902
# [2500]	validation_0-auc:0.91891
# [2600]	validation_0-auc:0.91878
# [2700]	validation_0-auc:0.91863
# [2800]	validation_0-auc:0.91850
# [2900]	validation_0-auc:0.91832
# [3000]	validation_0-auc:0.91820
# [3100]	validation_0-auc:0.91805
# [3200]	validation_0-auc:0.91791
# [3300]	validation_0-auc:0.91777
# [3400]	validation_0-auc:0.91764
# [3500]	validation_0-auc:0.91750
# [3600]	validation_0-auc:0.91732
# [3700]	validation_0-auc:0.91713
# [3800]	validation_0-auc:0.91693
# [3900]	validation_0-auc:0.91683
# [4000]	validation_0-auc:0.91675
# [4100]	validation_0-auc:0.91667
# [4200]	validation_0-auc:0.91651
# [4300]	validation_0-auc:0.91640
# [4400]	validation_0-auc:0.91627
# [4500]	validation_0-auc:0.91617
# [4600]	validation_0-auc:0.91605
# [4700]	validation_0-auc:0.91594
# [4800]	validation_0-auc:0.91579
# [4900]	validation_0-auc:0.91564
# [4979]	validation_0-auc:0.91555
# Fold 3 ROC AUC: 0.92052
# [0]	validation_0-auc:0.90722
# [100]	validation_0-auc:0.91665
# [200]	validation_0-auc:0.91850
# [300]	validation_0-auc:0.91945
# [400]	validation_0-auc:0.92019
# [500]	validation_0-auc:0.92062
# [600]	validation_0-auc:0.92096
# [700]	validation_0-auc:0.92108
# [800]	validation_0-auc:0.92112
# [900]	validation_0-auc:0.92115
# [1000]	validation_0-auc:0.92108
# [1100]	validation_0-auc:0.92108
# [1200]	validation_0-auc:0.92101
# [1300]	validation_0-auc:0.92092
# [1400]	validation_0-auc:0.92081
# [1500]	validation_0-auc:0.92068
# [1600]	validation_0-auc:0.92054
# [1700]	validation_0-auc:0.92037
# [1800]	validation_0-auc:0.92022
# [1900]	validation_0-auc:0.92008
# [2000]	validation_0-auc:0.91996
# [2100]	validation_0-auc:0.91980
# [2200]	validation_0-auc:0.91964
# [2300]	validation_0-auc:0.91955
# [2400]	validation_0-auc:0.91943
# [2500]	validation_0-auc:0.91929
# [2600]	validation_0-auc:0.91912
# [2700]	validation_0-auc:0.91893
# [2800]	validation_0-auc:0.91877
# [2900]	validation_0-auc:0.91856
# [3000]	validation_0-auc:0.91842
# [3100]	validation_0-auc:0.91828
# [3200]	validation_0-auc:0.91815
# [3300]	validation_0-auc:0.91799
# [3400]	validation_0-auc:0.91784
# [3500]	validation_0-auc:0.91767
# [3600]	validation_0-auc:0.91751
# [3700]	validation_0-auc:0.91734
# [3800]	validation_0-auc:0.91717
# [3900]	validation_0-auc:0.91704
# [4000]	validation_0-auc:0.91691
# [4100]	validation_0-auc:0.91673
# [4200]	validation_0-auc:0.91657
# [4300]	validation_0-auc:0.91645
# [4400]	validation_0-auc:0.91634
# [4500]	validation_0-auc:0.91621
# [4600]	validation_0-auc:0.91607
# [4700]	validation_0-auc:0.91593
# [4800]	validation_0-auc:0.91576
# [4897]	validation_0-auc:0.91564
# Fold 4 ROC AUC: 0.92116
# [0]	validation_0-auc:0.90664
# [100]	validation_0-auc:0.91628
# [200]	validation_0-auc:0.91815
# [300]	validation_0-auc:0.91922
# [400]	validation_0-auc:0.92008
# [500]	validation_0-auc:0.92053
# [600]	validation_0-auc:0.92077
# [700]	validation_0-auc:0.92092
# [800]	validation_0-auc:0.92096
# [900]	validation_0-auc:0.92100
# [1000]	validation_0-auc:0.92093
# [1100]	validation_0-auc:0.92090
# [1200]	validation_0-auc:0.92088
# [1300]	validation_0-auc:0.92081
# [1400]	validation_0-auc:0.92077
# [1500]	validation_0-auc:0.92064
# [1600]	validation_0-auc:0.92052
# [1700]	validation_0-auc:0.92037
# [1800]	validation_0-auc:0.92026
# [1900]	validation_0-auc:0.92015
# [2000]	validation_0-auc:0.92003
# [2100]	validation_0-auc:0.91989
# [2200]	validation_0-auc:0.91977
# [2300]	validation_0-auc:0.91957
# [2400]	validation_0-auc:0.91947
# [2500]	validation_0-auc:0.91932
# [2600]	validation_0-auc:0.91914
# [2700]	validation_0-auc:0.91897
# [2800]	validation_0-auc:0.91884
# [2900]	validation_0-auc:0.91871
# [3000]	validation_0-auc:0.91855
# [3100]	validation_0-auc:0.91845
# [3200]	validation_0-auc:0.91830
# [3300]	validation_0-auc:0.91814
# [3400]	validation_0-auc:0.91801
# [3500]	validation_0-auc:0.91788
# [3600]	validation_0-auc:0.91772
# [3700]	validation_0-auc:0.91758
# [3800]	validation_0-auc:0.91742
# [3900]	validation_0-auc:0.91728
# [4000]	validation_0-auc:0.91709
# [4100]	validation_0-auc:0.91696
# [4200]	validation_0-auc:0.91683
# [4300]	validation_0-auc:0.91670
# [4400]	validation_0-auc:0.91657
# [4500]	validation_0-auc:0.91644
# [4600]	validation_0-auc:0.91630
# [4700]	validation_0-auc:0.91616
# [4800]	validation_0-auc:0.91603
# [4845]	validation_0-auc:0.91597
# Fold 5 ROC AUC: 0.92102
#
# Average CV ROC AUC: 0.92157
# OOF ROC AUC: 0.92156

# %% [markdown]
# * Average CV ROC AUC: 0.92155
# * OOF ROC AUC: 0.92155

# %% [markdown]
# ## 4. Submission Generation

# %%
submission = pd.DataFrame({
    'id': test_df['id'],
    'loan_paid_back': test_preds
})

submission.to_csv('submission_xgboost_1.csv', index=False)
print("Submission saved to submission.csv")
submission.head()
# Out:
# Submission saved to submission.csv
#        id  loan_paid_back
# 0  593994        0.787539
# 1  593995        0.920654
# 2  593996        0.206161
# 3  593997        0.719640
# 4  593998        0.903030
